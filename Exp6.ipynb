# %%
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer as Vectorizer
from classifiers import TransparentMultinomialNB as Classifier
from utils import ce_squared, load_imdb
from pickle import dump
from time import time, sleep
import numpy as np
import multiprocessing as mp

# %%
def produce_modifications(in_q, out_q):
    global experimenting
    process_name = mp.current_process().name
    while experimenting:
        if not in_q.empty():
            y_train, train_indices, target_indices, current_error = in_q.get()   
            print('Producer got an item from the queue')
            for i in target_indices:
                mod0 = np.copy(y_train)
                mod0[i] = 1 - mod0[i]
                test = mod0, train_indices, current_error
                out_q.put(test)
                
                mod1 = list(train_indices)
                mod1.remove(i)
                test = y_train, mod1, current_error
                out_q.put(test)
        else:
            sleep(0.01)

# %%
def test_modification(in_q, out_q, X_train, X_val, y_val_na):
    global experimenting
    process_name = mp.current_process().name
    while experimenting:
        if not in_q.empty():
            y_train, train_indices, current_error = in_q.get()
            print('{} got an item from the queue'.format(process_name))
            clf = Classifier()
            clf.fit(X_train[train_indices],y_train[train_indices])
            new_error = ce_squared(y_val_na, clf.predict_proba(X_val))
            if new_error < current_error:
                result = True, new_error, y_train, train_indices
            else:
                result = False, current_error, y_train, train_indices
            out_q.put(result)
            print('{} finished'.format(process_name))
        else:
            sleep(0.01)

# %%
def select_best(in_q, out_q, X_train):
    global experimenting
    global best_error
    global best_y_train
    global best_train_indices
    
    experiment_length = 2 * X_train.shape[0]
    batch_size = 1
    round_length = 2 * batch_size # One for changing, one for omitting
    start_ind = 0
    end_ind = start_ind + batch_size
    i = 0
    j = 0
    
    initial_batch = best_y_train, best_train_indices, range(start_ind, end_ind), best_error
    out_q.put(initial_batch)
    print('Experiment started')
        
    while experimenting:
        if not in_q.empty():
            improved, try_error, try_y_train, try_train_indices = in_q.get()

            if improved and try_error < best_error:
                best_error = try_error
                best_y_train = try_y_train
                best_train_indices = try_train_indices

            i += 1
            j += 1
            print(i)
            if j == experiment_length:
                experimenting = False
                print('Experiment finished.')
                break

            if i == round_length: 
                start_ind += batch_size
                end_ind += batch_size
                next_batch = best_y_train, best_train_indices, range(start_ind, end_ind), best_error
                out_q.put(next_batch)
                print('Round: {}\tCurrent Error: {}'.format(j/round_length, best_error))
                i = 0
        else:
            sleep(0.01)

# %% [markdown]
# # Loading

# %%
t0 = time()

vect = Vectorizer(min_df=5, max_df=1.0, binary=False, ngram_range=(1, 1))

X_train, y_train, X_test, y_test, train_corpus, test_corpus = load_imdb("./aclImdb", shuffle=True, vectorizer=vect)

y_test_na = y_test[:, np.newaxis]
y_test_na = np.append(y_test_na, 1-y_test_na, axis=1)

clf = Classifier()
clf.fit(X_train, y_train)
best_clf = clf
ctrl_clf = clf

# Split the train dataset in 2 for validation
split = int(X_train.shape[0] / 2)

X_val = csr_matrix(X_train[split:])
y_val = np.copy(y_train[split:])

X_train = csr_matrix(X_train[:split])
y_train = np.copy(y_train[:split])

y_val_na = y_val[:, np.newaxis]
y_val_na = np.append(y_val_na, 1-y_val_na, axis=1)

train_indices = list(range(X_train.shape[0]))

best_error= ce_squared(y_test_na, clf.predict_proba(X_test))
best_y_train = np.copy(y_train)
best_train_indices = list(train_indices)

production_q = mp.Queue()
testing_q = mp.Queue()
selection_q = mp.Queue()

producer_task = mp.Process(target=produce_modifications, args=(production_q, testing_q))

testing_tasks = []
for _ in range(2):
    task = mp.Process(target=test_modification, args=(testing_q, selection_q, X_train, X_val, y_val_na))
    testing_tasks.append(task)
    
selection_task = mp.Process(target=select_best, args=(selection_q, production_q, X_train))

duration = time() - t0
print("Loading the experiment took {:0.2f}s.".format(duration), '\n')
# Out:
# Loading the imdb reviews data
# Data loaded.
# Extracting features from the training dataset using a sparse vectorizer
# Feature extraction technique is CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None).
# done in 5.803551912307739s
# (25000, 27272)
# n_samples: 25000, n_features: 27272
#
# Extracting features from the test dataset using the same vectorizer
# done in 5.407532453536987s
# n_samples: 25000, n_features: 27272
#
# Loading the experiment took 13.19s.

# %% [markdown]
# # Experiment

# %%
experimenting = True

selection_task.start()
producer_task.start()
for task in testing_tasks:
    task.start()

selection_task.join()
producer_task.join()
for task in testing_tasks:
    task.join()
# Out:
# Experiment started
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 1.0	Current Error: 0.14196490287083177
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Producer got an item from the queue
# Round: 2.0	Current Error: 0.1419448288720503
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 3.0	Current Error: 0.14192626241740586
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 4.0	Current Error: 0.14171962711738736
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 5.0	Current Error: 0.14171962711738736
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 6.0	Current Error: 0.14171947287452494
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# 1
# Process-3 finished
# Process-2 finished
# 2
# Round: 7.0	Current Error: 0.1417021665737583
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 8.0	Current Error: 0.14162965458190693
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 9.0	Current Error: 0.14162965458190693
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 10.0	Current Error: 0.14155836987925563
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 11.0	Current Error: 0.14155836987925563
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 12.0	Current Error: 0.1415270779637155
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 13.0	Current Error: 0.14151455480733877
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 14.0	Current Error: 0.14151455480733877
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 15.0	Current Error: 0.14148927155329155
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 16.0	Current Error: 0.14148927155329155
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 17.0	Current Error: 0.14148927155329155
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 18.0	Current Error: 0.14148927155329155
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 19.0	Current Error: 0.14146537863125871
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 20.0	Current Error: 0.14144256390863408
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 21.0	Current Error: 0.14144256390863408
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 22.0	Current Error: 0.14138585453672786
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 23.0	Current Error: 0.14138585453672786
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 24.0	Current Error: 0.14137140828174088
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 25.0	Current Error: 0.14132880653482485
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 26.0	Current Error: 0.14132880653482485
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 27.0	Current Error: 0.14132880653482485
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 28.0	Current Error: 0.14128711017392637
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 29.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-2 finished
# 1
# 2
# Process-3 finished
# Round: 30.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 31.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 32.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 33.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# Process-2 finished
# 1
# 2
# Round: 34.0	Current Error: 0.1412249806616244
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 35.0	Current Error: 0.14120460688722228
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 36.0	Current Error: 0.14120460688722228
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 37.0	Current Error: 0.14119092181196963
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 38.0	Current Error: 0.14119092181196963
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-2 finished
# 1
# Process-3 finished
# 2
# Round: 39.0	Current Error: 0.14112958177188048
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# 1
# Process-2 finished
# Process-3 finished
# 2
# Round: 40.0	Current Error: 0.14112958177188048
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 41.0	Current Error: 0.14112198916605315
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: 42.0	Current Error: 0.14112198916605315
# Producer got an item from the queue
# Process-3 got an item from the queue
# Process-2 got an item from the queue
# Process-2 finished
# Process-3 finished
# 1
# 2
# Round: 43.0	Current Error: 0.1410964791411912
# Producer got an item from the queue
# Process-2 got an item from the queue
# Process-3 got an item from the queue
# Process-3 finished
# 1
# Process-2 finished
# 2
# Round: